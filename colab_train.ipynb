# %% [markdown]
# # TERNARY - HGRN 340M
# Entrena MatMul-Free 48L/1536d en Shakespeare. ~3-5h en T4.

# %%
# !git clone https://github.com/mauro3422/Ternary.git
# %cd Ternary
import torch
print(f'GPU: {torch.cuda.get_device_name(0)}')

# %%
from config_350m_hgrn import HGRN350MConfig as GPTConfig

# %%
# !python train.py

# %%
# !python export.py
# !python sample.py

# %%
from google.colab import files
print('\nDescargar checkpoint.pt y engine/model.bin')
# files.download('checkpoint.pt')
# files.download('engine/model.bin')
