# %% [markdown]
# # TERNARY - HGRN 340M
# 48L/1536d MatMul-Free. Correr todo con Run All.

# %%
import os, shutil
os.chdir('/content')
shutil.rmtree('/content/Ternary', ignore_errors=True)
# !git clone https://github.com/mauro3422/Ternary.git
# %cd /content/Ternary
import torch
print(f'GPU: {torch.cuda.get_device_name(0)}')
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# fatal: could not create work tree dir 'Ternary': No such file or directory
# [Errno 2] No such file or directory: '/content/Ternary'
# /content/Ternary
# GPU: Tesla T4

# %%
CONFIG = 'config_350m_hgrn'
# Verificar config
from importlib import import_module
c = import_module(CONFIG)
cfg = [x for x in dir(c) if x.endswith('Config')][0]
conf = getattr(c, cfg)()
params_M = conf.n_layer * 3 * conf.n_embd * conf.n_embd / 1e6
print(f'Config: {CONFIG}.{cfg}')
print(f'Params: {params_M:.0f}M ({conf.n_layer}L, {conf.n_embd}d)')
assert params_M > 100, f'ERROR: {params_M:.0f}M es muy chico, no es HGRN 340M'
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_22394/27675699.py in <cell line: 0>()
#       2 # Verificar config
#       3 from importlib import import_module
# ----> 4 c = import_module(CONFIG)
#       5 cfg = [x for x in dir(c) if x.endswith('Config')][0]
#       6 conf = getattr(c, cfg)()
#
# /usr/lib/python3.12/importlib/__init__.py in import_module(name, package)
#      88                 break
#      89             level += 1
# ---> 90     return _bootstrap._gcd_import(name[level:], package, level)
#      91
#      92
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.12/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'config_350m_hgrn'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
# Exception ignored in atexit callback: <bound method InteractiveShell.atexit_operations of <google.colab._shell.Shell object at 0x7a44a54e94c0>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 3924, in atexit_operations
#     self.reset(new_session=False)
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py", line 1445, in reset
#     self.history_manager.reset(new_session)
#   File "/usr/local/lib/python3.12/dist-packages/google/colab/_history.py", line 33, in reset
#     super(ColabHistoryManager, self).reset(new_session=new_session)
#   File "/usr/local/lib/python3.12/dist-packages/IPython/core/history.py", line 592, in reset
#     self.dir_hist[:] = [os.getcwd()]
#                         ^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory

# %%
# !python train.py {CONFIG}
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# python3: can't open file 'train.py': [Errno 2] No such file or directory

# %%
# !python export.py {CONFIG}
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# python3: can't open file 'export.py': [Errno 2] No such file or directory

# %%
# !python sample.py {CONFIG} 'ROMEO:'
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# python3: can't open file 'sample.py': [Errno 2] No such file or directory

# %%
print('\n=== RESULTADOS ===')
import os
ckpt = os.path.getsize('checkpoint.pt') / 1e6
binf = os.path.getsize('engine/model.bin') / 1e6
print(f'checkpoint.pt: {ckpt:.1f} MB')
print(f'engine/model.bin: {binf:.1f} MB')
print('\nDescargar:')
from google.colab import files
# files.download('checkpoint.pt')
# files.download('engine/model.bin')
# Out:
# === RESULTADOS ===
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_22007/2905117489.py in <cell line: 0>()
#       1 print('\n=== RESULTADOS ===')
#       2 import os
# ----> 3 ckpt = os.path.getsize('checkpoint.pt') / 1e6
#       4 binf = os.path.getsize('engine/model.bin') / 1e6
#       5 print(f'checkpoint.pt: {ckpt:.1f} MB')
#
# /usr/lib/python3.12/genericpath.py in getsize(filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'checkpoint.pt'
