# %% [markdown]
# # TERNARY - Entrenamiento Colab
# HGRN 80M MatMul-Free. Run All (Ctrl+F9).

# %%
# !git clone https://github.com/mauro3422/Ternary.git
# %cd Ternary
import torch
print(f'GPU: {torch.cuda.get_device_name(0)}')

# %%
from config_85m_hgrn import HGRN80MConfig as GPTConfig
print(f'Config: HGRN 80M ({GPTConfig().n_layer}L, {GPTConfig().n_embd}d)')

# %%
# !python train.py

# %%
# !python export.py
# !python sample.py

# %%
from google.colab import files
print('\nDescargar:')
# files.download('checkpoint.pt')
# files.download('engine/model.bin')
