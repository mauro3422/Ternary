# %% [markdown]
# # Entrenamiento Ternario - Google Colab
# Subí los archivos a Colab o cloná el repo

# %%
# Opción 1: Subir archivos manualmente
from google.colab import files
print('Subí config.py, model.py, train.py, sample.py')
# uploaded = files.upload()
# Out:
# Subí config.py, model.py, train.py, sample.py

# %%
# Opción 2: Clonar el repo
# !git clone https://github.com/mauro3422/Ternary.git
# %cd Ternary
# Out:
# Cloning into 'Ternary'...
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 11 (delta 0), reused 11 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (11/11), 439.22 KiB | 2.30 MiB/s, done.
# /content/Ternary

# %%
import torch
print(f'CUDA disponible: {torch.cuda.is_available()}')
print(f'GPU: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else "N/A"}')
# Out:
# CUDA disponible: True
# GPU: Tesla T4

# %%
# !python train.py
# Out:
# Usando dispositivo: cuda
# Modo ternario: True
# Vocabulario: 65 caracteres
# Tamaño del dataset: 1115138 muestras
# Parámetros totales: 10,745,088
#   No decay (ternario): transformer.wte.weight
#   No decay (ternario): transformer.h.0.attn.c_attn.weight
#   No decay (ternario): transformer.h.0.attn.c_proj.weight
#   No decay (ternario): transformer.h.0.mlp.c_fc.weight
#   No decay (ternario): transformer.h.0.mlp.c_proj.weight
#   No decay (ternario): transformer.h.1.attn.c_attn.weight
#   No decay (ternario): transformer.h.1.attn.c_proj.weight
#   No decay (ternario): transformer.h.1.mlp.c_fc.weight
#   No decay (ternario): transformer.h.1.mlp.c_proj.weight
#   No decay (ternario): transformer.h.2.attn.c_attn.weight
#   No decay (ternario): transformer.h.2.attn.c_proj.weight
#   No decay (ternario): transformer.h.2.mlp.c_fc.weight
#   No decay (ternario): transformer.h.2.mlp.c_proj.weight
#   No decay (ternario): transformer.h.3.attn.c_attn.weight
# ...
