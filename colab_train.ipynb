# %% [markdown]
# # TERNARY - Entrenamiento en Colab
# Solo ejecutar Run All (Ctrl+F9).
#
# Por defecto entrena **HGRN 80M** (~1-2 h en T4).
# Para Transformer 10.7M, cambiar la config en la celda 2.

# %%
# !git clone https://github.com/mauro3422/Ternary.git
# %cd Ternary
import torch
print(f'GPU: {torch.cuda.get_device_name(0)}')

# %%
# --- CONFIG ---
# Opcion A: HGRN 80M (default, MatMul-Free)
from config_85m_hgrn import HGRN80MConfig as GPTConfig

# Opcion B: Transformer 10.7M (descomentar)
# from config import GPTConfig

print(f'Config: {GPTConfig().__class__.__name__}')
print(f'use_hgrn: {GPTConfig().use_hgrn}')

# %%
# !python train.py

# %%
# !python export.py
# !python sample.py

# %%
from google.colab import files
print('\nDescargar resultados:')
# files.download('checkpoint.pt')
# files.download('engine/model.bin')
